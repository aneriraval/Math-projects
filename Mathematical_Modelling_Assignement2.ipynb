# %%
#Ex 1.2 Q2:
import matplotlib.pyplot as plt
import numpy as np
year= [1790,1800,1810,1820,1830,1840,1850,1860,1870,1880,1890,1900,1910,1920,1930,
      1940,1950,1960,1970,1980,1990,2000,2010]
population= [3929,5308,7240,9638,12866,17069,23192,31443,38558,
                   50156,62948,75995,91972,105711,122755,131669,150697,
                   179323,203212,226505,248710,281416,308746]
population_scaled = [p * 1000 for p in population]
model_population=[3929000.0, 5047218.718234406, 6478645.740944815,8307747.70542863,
10639675.63737338, 13603986.23060123, 17358141.029355593, 22090053.95062255, 28018492.28207448,
35389531.79966591, 44466598.70930536, 55511123.20654752, 68750942.44853735, 84335067.4137216,
102277145.6674574, 122396359.76956356, 144272526.07962233, 167238033.76605046, 190426784.6492641,
212884457.82435468, 233717959.14887697, 252238717.0576801,268052079.2699727]
plt.plot(year,model_population)


plt.scatter (year,population_scaled)
plt.xlabel("Year")
plt.ylabel("Population")
plt.show()

# %%
x = np.zeros(25)
x[1] = 3929000

for i in range(1, len(x)-1):
    x[i+1] = 8.937 * 10**-10 * x[i] * (322387592.3- x[i]) + x[i]
    print(x[i])
# Out:
# 3929000.0
# 5047218.718234406
# 6478645.740944815
# 8307747.70542863
# 10639675.63737338
# 13603986.23060123
# 17358141.029355593
# 22090053.95062255
# 28018492.28207448
# 35389531.79966591
# 44466598.70930536
# 55511123.20654752
# 68750942.44853735
# 84335067.4137216
# 102277145.6674574
# 122396359.76956356
# 144272526.07962233
# 167238033.76605046
# 190426784.6492641
# 212884457.82435468
# 233717959.14887697
# 252238717.0576801
# 268052079.2699727

# %%
#Ex 1.3 Q3a:
import matplotlib.pyplot as plt
import numpy as np
n_steps=10
x = np.zeros(n_steps)
y = np.zeros(n_steps)
x[0]= 1000
for n in range(n_steps - 1):
  x[n+1]=-1.2*x[n]+50
plt.figure(figsize=(8,5))
plt.plot (range(n_steps),x)
plt.show()

# %%
#Ex 1.3 Q3b:
import matplotlib.pyplot as plt
import numpy as np
n_steps=10
x = np.zeros(n_steps)
y = np.zeros(n_steps)
x[0]= 500
for n in range(n_steps - 1):
  x[n+1]=0.8*x[n]-100
plt.figure(figsize=(8,5))
plt.plot (range(n_steps),x)
plt.show()

# %%
#Ex 1.3 Q3c:
import matplotlib.pyplot as plt
import numpy as np
n_steps=10
x = np.zeros(n_steps)
y = np.zeros(n_steps)
x[0]= -500
for n in range(n_steps - 1):
  x[n+1]=0.8*x[n]-100
plt.figure(figsize=(8,5))
plt.plot (range(n_steps),x)
plt.show()

# %%
#Ex 1.3 Q3d:
import matplotlib.pyplot as plt
import numpy as np
n_steps=10
x = np.zeros(n_steps)
y = np.zeros(n_steps)
x[0]= 1000
for n in range(n_steps - 1):
  x[n+1]=-0.8*x[n]+100
plt.figure(figsize=(8,5))
plt.plot (range(n_steps),x)
plt.show()

# %%
#Ex 1.3 Q3e:
import matplotlib.pyplot as plt
import numpy as np
n_steps=10
x = np.zeros(n_steps)
y = np.zeros(n_steps)
x[0]= 1000
for n in range(n_steps - 1):
  x[n+1]=x[n]-100
plt.figure(figsize=(8,5))
plt.plot (range(n_steps),x)
plt.show()

# %%
#Ex 3.2, Q2a:
import numpy as np
from scipy.optimize import linprog
problem2a= linprog(c=[1,0,0],
                   A_ub=[[-1,1,1],[-1,-1,-1],[-1,2.3,1],[-1,-2.3,-1],
                    [-1,-3.7,-1],[-1,3.7,1],[-1,4.2,1],[-1,-4.2,-1],
                     [-1,-6.1,-1],[-1,6.1,1],[-1,7,1],[-1,-7,-1]],
                  b_ub=np.array([3.6,-3.6,3,-3,-3.2,3.2,5.1,-5.1,-5.3,5.3,6.8,-6.8]), method= 'simplex')
print(problem2a)
# Out:
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 0.9199999999999994
#        x: [ 9.200e-01  5.333e-01  2.147e+00]
#      nit: 13
# <ipython-input-1-f66fee7ec709>:4: DeprecationWarning: `method='simplex'` is deprecated and will be removed in SciPy 1.11.0. Please use one of the HiGHS solvers (e.g. `method='highs'`) in new code.
#   problem2a= linprog(c=[1,0,0],

# %%
#Ex 3.2, Q2b:
from scipy.optimize import linprog
import numpy as np
problem2b= linprog(c=[1,0,0],
                   A_ub= [[-1,29.1,1],[-1,-29.1,-1],[-1,48.2,1],[-1,-48.2,-1],
                    [-1,72.7,1],[-1,-72.7,-1],[-1,92,1],[-1,-92,-1],
                     [-1,118,1],[-1,-118,-1],[-1,140,1],[-1,-140,-1],[-1,165,1],
                      [-1,-165,-1],[-1,199,1],[-1,-199,-1]],
                  b_ub=np.array([0.0493,-0.0493,0.0821,-0.0821,0.123,-0.123,0.154,-0.154,0.197,-0.197,0.234,-0.234,0.274,-0.274,0.328,-0.328]),
                   method= 'simplex')
print(problem2b)
# Out:
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 0.0013911124190700477
#        x: [ 1.391e-03  1.640e-03  2.956e-03]
#      nit: 16
# <ipython-input-2-5dd6e8bccee1>:4: DeprecationWarning: `method='simplex'` is deprecated and will be removed in SciPy 1.11.0. Please use one of the HiGHS solvers (e.g. `method='highs'`) in new code.
#   problem2b= linprog(c=[1,0,0],

# %%
#Ex 3.2, Q2c:
from scipy.optimize import linprog
import numpy as np
problem2c= linprog(c=[1,0,0],
                   A_ub= [[-1,-2.5,-1],[-1,2.5,1],[-1,-3,-1],[-1,3,1],
                    [-1,-3.5,-1],[-1,3.5,1],[-1,-4,-1],[-1,4,1],
                     [-1,-4.5,-1],[-1,4.5,1],[-1,-5,-1],[-1,5,1],
                      [-1,-5.5,-1],[-1,5.5,1]],
                  b_ub=np.array([-4.32,4.32,-4.83,4.83,-5.27,5.27,-5.74,5.74,-6.26,6.26,-6.79,6.79,-7.23,7.23]),
                   method= 'simplex')
print(problem2c)
# Out:
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 0.034999999999999934
#        x: [ 3.500e-02  9.800e-01  1.855e+00]
#      nit: 14
# <ipython-input-3-161831e2578d>:4: DeprecationWarning: `method='simplex'` is deprecated and will be removed in SciPy 1.11.0. Please use one of the HiGHS solvers (e.g. `method='highs'`) in new code.
#   problem2c= linprog(c=[1,0,0],

# %%
#Ex 3.2, Q3:
from scipy.optimize import linprog
import numpy as np
problem3= linprog(c=[1,0,0,0],
                   A_ub=np.array([[-1,0.01,0.1,1],[-1,-0.01,-0.1,-1],[-1,0.04,0.2,1],[-1,-0.04,-0.2,-1],
                    [-1,0.09,0.3,1],[-1,-0.09,-0.3,-1],[-1,0.16,0.4,1],[-1,-0.16,-0.4,-1],
                     [-1,0.25,0.5,1],[-1,-0.25,-0.5,-1]]),
                 b_ub=np.array([0.06,-0.06,0.12,-0.12,0.36,-0.36,0.65,-0.65,0.95,-0.95,]),
                   method= 'simplex')
print(problem3)
# Out:
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 0.03400000000000001
#        x: [ 3.400e-02  3.850e+00  0.000e+00  0.000e+00]
#      nit: 13
# <ipython-input-4-c2fef5f60998>:4: DeprecationWarning: `method='simplex'` is deprecated and will be removed in SciPy 1.11.0. Please use one of the HiGHS solvers (e.g. `method='highs'`) in new code.
#   problem3= linprog(c=[1,0,0,0],
